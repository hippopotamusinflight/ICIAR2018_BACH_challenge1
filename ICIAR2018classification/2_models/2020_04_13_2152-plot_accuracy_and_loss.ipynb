# %% [markdown]
# ## 2020_04_13_2152-plot_accuracy_and_loss

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
classification_dir = "/global/home/hpc4535/CISC881FinalProject/ICIAR2018classification/"
csv_dir = os.path.join(classification_dir, "2_pretrained_models_test/outputs/")
history_csv = "ResNet50_wDropout_p1400s100_73split_5plus150epochs.csv"

# %%
colnames = ["epoch","val_loss","val_accuracy","train_loss","train_accuracy"]
history = pd.read_csv(os.path.join(csv_dir, history_csv), skiprows=1, names=colnames)

# %%
history
# Out:
#      epoch  val_loss  val_accuracy  train_loss  train_accuracy
# 0        0  6.894886      0.605769    1.194124        0.765430
# 1        1  7.107090      0.634615    1.166935        0.767428
# 2        2  6.360963      0.622596    1.140618        0.767253
# 3        3  6.578369      0.638221    1.107469        0.771368
# 4        4  6.557519      0.625000    1.083185        0.773207
# ..     ...       ...           ...         ...             ...
# 145    145  0.656607      0.930288    0.346228        0.962540
# 146    146  0.691104      0.926250    0.331162        0.965234
# 147    147  0.317369      0.925481    0.332793        0.965388
# 148    148  0.513369      0.932692    0.335094        0.965478
# 149    149  0.553725      0.926683    0.330160        0.965495
#
# [150 rows x 5 columns]

# %%
plt.plot(history["val_loss"])
plt.plot(history["train_loss"])
plt.title("training and validation loss, \nResNet50, p1400s100")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["Validation", "Training"], loc="upper left")
plt.show()

# %%
plt.plot(history["val_accuracy"])
plt.plot(history["train_accuracy"])
plt.title("training and validation accuracy, \nResNet50, p1400s100")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["Validation", "Training"], loc="upper left")
plt.show()
